# %%
import requests

# %%
url = "http://localhost:5000"

# %%
res = requests.get(url)

# %%
res.json()
# Out:
# {'hello': 'World!'}

# %%
new_player = {
    "name":"Paquito",
    "last_name":"Montero",
    "place_of_birth":"Chinclana"
}

# %%
res = requests.get(url+"/insert/jugadores", params= new_player)

# %%
res.json()
# Out:
# {'_id': {'$oid': '5fbf96bc482aee9b5eb0f2a2'}}

# %%
import numpy as np
import datetime
import time

# %%
cars = np.random.normal(25,6,100)

# %%
for car in cars:
    measure = {
        "cars":int(car),
        "time":datetime.datetime.now()
    }
    requests.get(url+"/insert/traffic", params=measure)
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-40b6568be7ff> in <module>()
#       5     }
#       6     requests.get(url+"/insert/traffic", params=measure)
# ----> 7     time.sleep(5)
#
# KeyboardInterrupt:

# %%
res = requests.get(url+"/sql/sara_web_store.customers")

# %%
res.json()
# Out:
# [{'customer_id': 1,
#   'first_name': 'Russell',
#   'last_name': 'Farley',
#   'date_of_birth': {'$date': 988588800000},
#   'email': 'facilisis.eget.ipsum@miloremvehicula.net',
#   'phone': '915 605 739',
#   'mobile': '692 270039'},
#  {'customer_id': 2,
#   'first_name': 'Joshua',
#   'last_name': 'Carpenter',
#   'date_of_birth': {'$date': 570499200000},
#   'email': 'erat@semegetmassa.net',
#   'phone': '944 247 602',
#   'mobile': '614 505209'},
#  {'customer_id': 3,
#   'first_name': 'Suki',
#   'last_name': 'Henderson',
#   'date_of_birth': {'$date': -315792000000},
#   'email': 'lacus@arcuet.edu',
#   'phone': '961 034 087',
#   'mobile': '693 161065'},
#  {'customer_id': 4,
#   'first_name': 'Indigo',
#   'last_name': 'Meadows',
#   'date_of_birth': {'$date': 890524800000},
#   'email': 'diam.luctus.lobortis@Nam.co.uk',
#   'phone': '',
#   'mobile': '662 837817'},
#  {'customer_id': 5,
#   'first_name': 'Giacomo',
#   'last_name': 'Contreras',
# ...

# %%
users = ["Pepe", "Maria", "Paco"]
for u in users:
    request.get("miapi/user/add", params = {"user"::u})
