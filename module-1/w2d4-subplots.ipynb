# %% [markdown]
# # Subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.random(10)
x1 = np.random.random(10)

# %% [markdown]
# # Opción 1

# %%
plt.figure(figsize=(12,3)) # Dimensiones del grafico
plt.subplot(1,2,1) # (nrows, ncols, index)
plt.title("Habitación 1")
plt.ylabel("Temperatura (K)")
plt.xlabel("Tiempo (H)")
plt.plot(x)

plt.subplot(1,2,2)
plt.title("Habitación 2")
plt.ylabel("Presion (mmHg)")
plt.xlabel("Tiempo (d)")
plt.plot(x1)

# %% [markdown]
# # Opción 2

# %%
fig,a = plt.subplots(2,2)
a[0][0].plot(x)
a[0][1].plot(x1)
a[1][0].scatter(x,x1)
a[0][0].set_title("hola")
plt.show()

# %%
plt.plot(x)

# %% [markdown]
# https://matplotlib.org/3.3.2/api/_as_gen/matplotlib.pyplot.subplots.html

# %% [markdown]
# # Seaborn

# %% [markdown]
# https://seaborn.pydata.org/tutorial.html#

# %%
import seaborn as sns
sns.set()

# %%
sns.scatterplot(data=x)
